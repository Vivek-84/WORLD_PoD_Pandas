# %%
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\VIVEK\\Downloads\\World_Po.csv")

# %%
data
# Out:
#     Country (or dependency)  Population(2020)  Yearly_change       Net  \
# 0                     China        1439323776         0.0039   5540090
# 1                     India        1380004385         0.0099  13586631
# 2             United States         331002651         0.0059   1937734
# 3                 Indonesia         273523615         0.0107   2898047
# 4                  Pakistan         220892340         0.0200   4327022
# ..                      ...               ...            ...       ...
# 230              Montserrat              4992         0.0006         3
# 231        Falkland Islands              3480         0.0305       103
# 232                    Niue              1626         0.0068        11
# 233                 Tokelau              1357         0.0127        17
# 234                Holy See               801         0.0025         2
#
#      Density(P/km2)  Land Area(Km2)  Migrants Fert. Rate Med.Age Urban Pop%  \
# ...

# %%
data1=data.loc[ : ,["Country (or dependency)","Density(P/km2)"]]

# %%
data1
# Out:
#     Country (or dependency)  Density(P/km2)
# 0                     China             153
# 1                     India             464
# 2             United States              36
# 3                 Indonesia             151
# 4                  Pakistan             287
# ..                      ...             ...
# 230              Montserrat              50
# 231        Falkland Islands               0
# 232                    Niue               6
# 233                 Tokelau             136
# 234                Holy See            2003
#
# [235 rows x 2 columns]

# %%
df=pd.DataFrame({"Country (or dependency)":['Guinea','Iran','Trinidad and Tobago','Honduras','Lebanon','Ethiopia','Niger','Afghanistan','India', 
                 'American Samoa','Cuba','Gabon','Nicaragua','Channel Islands',
'Martinique']})

# %%
df
# Out:
#    Country (or dependency)
# 0                   Guinea
# 1                     Iran
# 2      Trinidad and Tobago
# 3                 Honduras
# 4                  Lebanon
# 5                 Ethiopia
# 6                    Niger
# 7              Afghanistan
# 8                    India
# 9           American Samoa
# 10                    Cuba
# 11                   Gabon
# 12               Nicaragua
# 13         Channel Islands
# 14              Martinique

# %%
data2=pd.merge(data1,df, on="Country (or dependency)",how="inner")

# %%
data2
# Out:
#    Country (or dependency)  Density(P/km2)
# 0                    India             464
# 1                 Ethiopia             115
# 2                     Iran              52
# 3              Afghanistan              60
# 4                    Niger              19
# 5                   Guinea              53
# 6                     Cuba             106
# 7                 Honduras              89
# 8                  Lebanon             667
# 9                Nicaragua              55
# 10                   Gabon               9
# 11     Trinidad and Tobago             273
# 12              Martinique             354
# 13         Channel Islands             915
# 14          American Samoa             276

# %%
data_modified=data2.sort_values("Density(P/km2)",ascending=False)

# %%
data_modified
# Out:
#    Country (or dependency)  Density(P/km2)
# 13         Channel Islands             915
# 8                  Lebanon             667
# 0                    India             464
# 12              Martinique             354
# 14          American Samoa             276
# 11     Trinidad and Tobago             273
# 1                 Ethiopia             115
# 6                     Cuba             106
# 7                 Honduras              89
# 3              Afghanistan              60
# 9                Nicaragua              55
# 5                   Guinea              53
# 2                     Iran              52
# 4                    Niger              19
# 10                   Gabon               9

# %%
data_modified["Country (or dependency)"].apply(lambda x:x[0])
# Out:
# 13    C
# 8     L
# 0     I
# 12    M
# 14    A
# 11    T
# 1     E
# 6     C
# 7     H
# 3     A
# 9     N
# 5     G
# 2     I
# 4     N
# 10    G
# Name: Country (or dependency), dtype: object
